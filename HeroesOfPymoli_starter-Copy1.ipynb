# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
count = purchase_data["SN"].value_counts()
total_players = len(count)
total_players
# Out:
# 576

# %%
#Player Count Answer

totalplayer_table = pd.DataFrame({"Total Players": [total_players]})
totalplayer_table
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique = purchase_data["Item ID"].unique()
unique_items = len(unique)
unique_items
# Out:
# 183

# %%
unique_p = purchase_data["Purchase ID"].unique()
unique_purchase = len(unique_p)
unique_purchase
# Out:
# 780

# %%
revenue = purchase_data["Price"].sum()
revenue
# Out:
# 2379.77

# %%
avg_price = purchase_data["Price"].mean()
avg_price
# Out:
# 3.050987179487176

# %%
#Purcahsing Analysis (Total) Answer

purchasing_analysis = pd.DataFrame({"Number of Unique Items": [unique_items], 
                                    "Average Price": [avg_price], 
                                    "Number of Purchases": [unique_purchase], 
                                    "Total Revenue": [revenue]})
purchasing_analysis
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     183       3.050987                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
male_only = purchase_data.loc[purchase_data["Gender"] == "Male", :]

male_only.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
unique_male = male_only["SN"].unique()
unique_male = len(unique_male)
unique_male
# Out:
# 484

# %%
female_only = purchase_data.loc[purchase_data["Gender"] == "Female", :]

female_only.head()
# Out:
#     Purchase ID         SN  Age  Gender  Item ID  \
# 15           15  Lisassa64   21  Female       98
# 18           18  Reunasu60   22  Female       82
# 38           38   Reulae52   10  Female      116
# 41           41  Assosia88   20  Female        7
# 55           55  Phaelap26   25  Female       84
#
#                        Item Name  Price
# 15   Deadline, Voice Of Subtlety   2.89
# 18                       Nirvana   4.90
# 38       Renewed Skeletal Katana   4.18
# 41  Thorn, Satchel of Dark Souls   1.33
# 55                    Arcane Gem   3.79

# %%
unique_female = female_only["SN"].unique()
unique_female = len(unique_female)
unique_female
# Out:
# 81

# %%
other_only = purchase_data.loc[purchase_data["Gender"] == "Other / Non-Disclosed", :]

other_only.head()
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
#
#                         Item Name  Price
# 9    Ghastly Adamantite Protector   3.58
# 22                  Warped Fetish   3.81
# 82                     Azurewrath   4.40
# 111                         Orbit   4.75
# 228                     Dreamsong   3.39

# %%
unique_other = other_only["SN"].unique()
unique_other = len(unique_other)
unique_other
# Out:
# 11

# %%
male_percentage = (unique_male/total_players)*100
male_percentage
# Out:
# 84.02777777777779

# %%
female_percentage = (unique_female/total_players)*100
female_percentage
# Out:
# 14.0625

# %%
other_percentage = (unique_other/total_players)*100
unique_other
# Out:
# 11

# %%
gender_demo = pd.DataFrame([{"Total Count": unique_male, "Percentage of Players": male_percentage, "Gender": "Male"},
                            {"Total Count": unique_female, "Percentage of Players": female_percentage, "Gender": "Female"},
                            {"Total Count": unique_other, "Percentage of Players": unique_other, "Gender": "Other"}])
                                    
gender_demo
# Out:
#    Gender  Percentage of Players  Total Count
# 0    Male              84.027778          484
# 1  Female              14.062500           81
# 2   Other              11.000000           11

# %%
#Gender Demographics Answer

gender_demo = gender_demo.set_index("Gender")
gender_demo.head()
# Out:
#         Percentage of Players  Total Count
# Gender
# Male                84.027778          484
# Female              14.062500           81
# Other               11.000000           11

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
male_purchase = male_only["Purchase ID"].value_counts()
male_purchase = len(male_purchase)
male_purchase
# Out:
# 652

# %%
female_purchase = female_only["Purchase ID"].value_counts()
female_purchase = len(female_purchase)
female_purchase
# Out:
# 113

# %%
other_purchase = other_only["Purchase ID"].value_counts()
other_purchase = len(other_purchase)
other_purchase
# Out:
# 15

# %%
male_avg_purchase = male_only["Price"].mean()
male_avg_purchase
# Out:
# 3.0178527607361953

# %%
female_avg_purchase = female_only["Price"].mean()
female_avg_purchase
# Out:
# 3.203008849557519

# %%
other_avg_purchase = other_only["Price"].mean()
other_avg_purchase
# Out:
# 3.3460000000000005

# %%
male_total_purchase = male_only["Price"].sum()
male_total_purchase
# Out:
# 1967.64

# %%
female_total_purchase = female_only["Price"].sum()
female_total_purchase
# Out:
# 361.94

# %%
other_total_purchase = other_only["Price"].sum()
other_total_purchase
# Out:
# 50.19

# %%
male_avgpurchase_perperson = (male_total_purchase/unique_male)
male_avgpurchase_perperson
# Out:
# 4.065371900826446

# %%
female_avgpurchase_perperson = (female_total_purchase/unique_female)
female_avgpurchase_perperson
# Out:
# 4.468395061728395

# %%
other_avgpurchase_perperson = (other_total_purchase/unique_other)
other_avgpurchase_perperson
# Out:
# 4.5627272727272725

# %%
gender_purchasing_analysis = pd.DataFrame([{"Purchase Count": male_purchase, "Average Purchase Price": male_avg_purchase, "Gender": "Male", "Total Purcahse Value": male_total_purchase, "Avg Total Purchase per Person": male_avgpurchase_perperson},
                            {"Purchase Count": female_purchase, "Average Purchase Price": female_avg_purchase, "Gender": "Female", "Total Purcahse Value": female_total_purchase, "Avg Total Purchase per Person": female_avgpurchase_perperson},
                            {"Purchase Count": other_purchase, "Average Purchase Price": other_avg_purchase, "Gender": "Other", "Total Purcahse Value": other_total_purchase, "Avg Total Purchase per Person": other_avgpurchase_perperson}])
                                    
gender_purchasing_analysis
# Out:
#    Average Purchase Price  Avg Total Purchase per Person  Gender  \
# 0                3.017853                       4.065372    Male
# 1                3.203009                       4.468395  Female
# 2                3.346000                       4.562727   Other
#
#    Purchase Count  Total Purcahse Value
# 0             652               1967.64
# 1             113                361.94
# 2              15                 50.19

# %%
#Purchasing Analysis by Gender Answer
gender_purchasing_analysis = gender_purchasing_analysis.set_index("Gender")
gender_purchasing_analysis.head()
# Out:
#         Average Purchase Price  Avg Total Purchase per Person  Purchase Count  \
# Gender
# Male                  3.017853                       4.065372             652
# Female                3.203009                       4.468395             113
# Other                 3.346000                       4.562727              15
#
#         Total Purcahse Value
# Gender
# Male                 1967.64
# Female                361.94
# Other                  50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0, 10, 15, 20, 25, 30, 35, 40, 100]

group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
lessten = purchase_data.loc[purchase_data["Age"] < 10, :]

lessten.head()
# Out:
#     Purchase ID            SN  Age  Gender  Item ID  \
# 27           27       Eusri44    7    Male       96
# 33           33  Haillyrgue51    7    Male       44
# 37           37     Seuthep89    8    Male       73
# 78           78  Haillyrgue51    7    Male       50
# 81           81      Heudai45    8  Female      174
#
#                       Item Name  Price
# 27  Blood-Forged Skeletal Spine   3.09
# 33        Bonecarvin Battle Axe   2.38
# 37                  Ritual Mace   2.05
# 78                         Dawn   4.60
# 81              Primitive Blade   3.47

# %%
less_than_ten = lessten["SN"].unique()
less_than_ten = len(less_than_ten)
less_than_ten
# Out:
# 17

# %%
lessten_purchasecount = lessten["Purchase ID"].value_counts()
lessten_purchasecount = len(lessten_purchasecount)
lessten_purchasecount
# Out:
# 23

# %%
lessten_avgpurchase = lessten["Price"].mean()

lessten_avgpurchase
# Out:
# 3.353478260869565

# %%
lessten_totalpurchase = lessten["Price"].sum()

lessten_totalpurchase
# Out:
# 77.13

# %%
lessten_avgtotalperperson = lessten_totalpurchase/less_than_ten
lessten_avgtotalperperson
# Out:
# 4.537058823529412

# %%
lessten_avg_per_person = lessten_totalpurchase/less_than_ten
lessten_avg_per_person
# Out:
# 4.537058823529412

# %%
tentofourteen = purchase_data.loc[purchase_data["Age"].between(10, 14)]

# %%
#unique players between 10-14 
tentofourteen_unique_players = tentofourteen["SN"].unique()
tentofourteen_unique_players = len(tentofourteen_unique_players)
tentofourteen_unique_players
# Out:
# 22

# %%
#purchase count for 10-14

tentofourteen_purchasecount = tentofourteen["Purchase ID"].value_counts()
tentofourteen_purchasecount = len(tentofourteen_purchasecount)
tentofourteen_purchasecount
# Out:
# 28

# %%
tentofourteen_avgpurchase = tentofourteen["Price"].mean()

tentofourteen_avgpurchase
# Out:
# 2.956428571428571

# %%
tentofourteen_totalpurchase = tentofourteen["Price"].sum()

tentofourteen_totalpurchase
# Out:
# 82.78

# %%
tentofourteen_avg_per_person = tentofourteen_totalpurchase/tentofourteen_unique_players
tentofourteen_avg_per_person
# Out:
# 3.7627272727272727

# %%
fifteentonineteen = purchase_data.loc[purchase_data["Age"].between(15, 19)]

# %%
#unique players

fifteentonineteen_unique_players = fifteentonineteen["SN"].unique()
fifteentonineteen_unique_players = len(fifteentonineteen_unique_players)
fifteentonineteen_unique_players


#purchase count
fifteentonineteen_purchasecount = fifteentonineteen["Purchase ID"].value_counts()
fifteentonineteen_purchasecount = len(fifteentonineteen_purchasecount)
fifteentonineteen_purchasecount

#average
fifteentonineteen_avgpurchase = fifteentonineteen["Price"].mean()
fifteentonineteen_avgpurchase


#total
fifteentonineteen_totalpurchase = fifteentonineteen["Price"].sum()
fifteentonineteen_totalpurchase


#avg per person
fifteentonineteen_avg_per_person = fifteentonineteen_totalpurchase/fifteentonineteen_unique_players
fifteentonineteen_avg_per_person
# Out:
# 3.858785046728972

# %%
twentytotwentyfour = purchase_data.loc[purchase_data["Age"].between(20, 24)]

# %%
#unique players

twentytotwentyfour_unique_players = twentytotwentyfour["SN"].unique()
twentytotwentyfour_unique_players = len(twentytotwentyfour_unique_players)
twentytotwentyfour_unique_players


#purchase count
twentytotwentyfour_purchasecount = twentytotwentyfour["Purchase ID"].value_counts()
twentytotwentyfour_purchasecount = len(twentytotwentyfour_purchasecount)
twentytotwentyfour_purchasecount

#average
twentytotwentyfour_avgpurchase = twentytotwentyfour["Price"].mean()
twentytotwentyfour_avgpurchase


#total
twentytotwentyfour_totalpurchase = twentytotwentyfour["Price"].sum()
twentytotwentyfour_totalpurchase


#avg per person
twentytotwentyfour_avg_per_person = twentytotwentyfour_totalpurchase/twentytotwentyfour_unique_players
twentytotwentyfour_avg_per_person
# Out:
# 4.318062015503876

# %%
twentyfivetotwentynine = purchase_data.loc[purchase_data["Age"].between(25, 29)]

# %%
#unique players

twentyfivetotwentynine_unique_players = twentyfivetotwentynine["SN"].unique()
twentyfivetotwentynine_unique_players = len(twentyfivetotwentynine_unique_players)
twentyfivetotwentynine_unique_players


#purchase count
twentyfivetotwentynine_purchasecount = twentyfivetotwentynine["Purchase ID"].value_counts()
twentyfivetotwentynine_purchasecount = len(twentyfivetotwentynine_purchasecount)
twentyfivetotwentynine_purchasecount

#average
twentyfivetotwentynine_avgpurchase = twentyfivetotwentynine["Price"].mean()
twentyfivetotwentynine_avgpurchase


#total
twentyfivetotwentynine_totalpurchase = twentyfivetotwentynine["Price"].sum()
twentyfivetotwentynine_totalpurchase


#avg per person
twentyfivetotwentynine_avg_per_person = twentyfivetotwentynine_totalpurchase/twentyfivetotwentynine_unique_players
twentyfivetotwentynine_avg_per_person
# Out:
# 3.8051948051948044

# %%
thirtytothirtyfour = purchase_data.loc[purchase_data["Age"].between(30, 34)]

# %%
#unique players

thirtytothirtyfour_unique_players = thirtytothirtyfour["SN"].unique()
thirtytothirtyfour_unique_players = len(thirtytothirtyfour_unique_players)
thirtytothirtyfour_unique_players


#purchase count
thirtytothirtyfour_purchasecount = thirtytothirtyfour["Purchase ID"].value_counts()
thirtytothirtyfour_purchasecount = len(thirtytothirtyfour_purchasecount)
thirtytothirtyfour_purchasecount

#average
thirtytothirtyfour_avgpurchase = thirtytothirtyfour["Price"].mean()
thirtytothirtyfour_avgpurchase


#total
thirtytothirtyfour_totalpurchase = thirtytothirtyfour["Price"].sum()
thirtytothirtyfour_totalpurchase


#avg per person
thirtytothirtyfour_avg_per_person = thirtytothirtyfour_totalpurchase/thirtytothirtyfour_unique_players
thirtytothirtyfour_avg_per_person
# Out:
# 4.115384615384616

# %%
thirtyfivetothirtythirtynine = purchase_data.loc[purchase_data["Age"].between(35, 39)]

# %%
#unique players

thirtyfivetothirtythirtynine_unique_players = thirtyfivetothirtythirtynine["SN"].unique()
thirtyfivetothirtythirtynine_unique_players = len(thirtyfivetothirtythirtynine_unique_players)
thirtyfivetothirtythirtynine_unique_players


#purchase count
thirtyfivetothirtythirtynine_purchasecount = thirtyfivetothirtythirtynine["Purchase ID"].value_counts()
thirtyfivetothirtythirtynine_purchasecount = len(thirtyfivetothirtythirtynine_purchasecount)
thirtyfivetothirtythirtynine_purchasecount

#average
thirtyfivetothirtythirtynine_avgpurchase = thirtyfivetothirtythirtynine["Price"].mean()
thirtyfivetothirtythirtynine_avgpurchase


#total
thirtyfivetothirtythirtynine_totalpurchase = thirtyfivetothirtythirtynine["Price"].sum()
thirtyfivetothirtythirtynine_totalpurchase


#avg per person
thirtyfivetothirtythirtynine_avg_per_person = thirtyfivetothirtythirtynine_totalpurchase/thirtyfivetothirtythirtynine_unique_players
thirtyfivetothirtythirtynine_avg_per_person
# Out:
# 4.763548387096773

# %%
fourtyplus = purchase_data.loc[purchase_data["Age"] > 40, :]

# %%
#unique players

fourtyplus_unique_players = fourtyplus["SN"].unique()
fourtyplus_unique_players = len(fourtyplus_unique_players)
fourtyplus_unique_players


#purchase count
fourtyplus_purchasecount = fourtyplus["Purchase ID"].value_counts()
fourtyplus_purchasecount = len(fourtyplus_purchasecount)
fourtyplus_purchasecount

#average
fourtyplus_avgpurchase = fourtyplus["Price"].mean()
fourtyplus_avgpurchase


#total
fourtyplus_totalpurchase = fourtyplus["Price"].sum()
fourtyplus_totalpurchase


#avg per person
fourtyplus_avg_per_person = fourtyplus_totalpurchase/fourtyplus_unique_players
fourtyplus_avg_per_person
# Out:
# 3.075714285714285

# %%
#Age Demographics

age_purchasing_analysis = pd.DataFrame([{"Age": "<10", "Purchase Count": lessten_purchasecount, "Average Purchase Price": lessten_avgpurchase, "Total Purchase Value": lessten_totalpurchase, "Avg Total Purchase per Person": lessten_avg_per_person},
                                        {"Age": "10-14", "Purchase Count": tentofourteen_purchasecount, "Average Purchase Price": tentofourteen_avgpurchase, "Total Purchase Value": tentofourteen_totalpurchase, "Avg Total Purchase per Person": tentofourteen_avg_per_person},
                                       {"Age": "15-19", "Purchase Count": fifteentonineteen_purchasecount, "Average Purchase Price": fifteentonineteen_avgpurchase, "Total Purchase Value": fifteentonineteen_totalpurchase, "Avg Total Purchase per Person": fifteentonineteen_avg_per_person},
                                        {"Age": "20-24", "Purchase Count": twentytotwentyfour_purchasecount, "Average Purchase Price": twentytotwentyfour_avgpurchase, "Total Purchase Value": twentytotwentyfour_totalpurchase, "Avg Total Purchase per Person": twentytotwentyfour_avg_per_person},
                                       {"Age": "25-29", "Purchase Count": twentyfivetotwentynine_purchasecount, "Average Purchase Price": twentyfivetotwentynine_avgpurchase, "Total Purchase Value": twentyfivetotwentynine_totalpurchase, "Avg Total Purchase per Person": twentyfivetotwentynine_avg_per_person},
                                       {"Age": "30-34", "Purchase Count": thirtytothirtyfour_purchasecount, "Average Purchase Price": thirtytothirtyfour_avgpurchase, "Total Purchase Value": thirtytothirtyfour_totalpurchase, "Avg Total Purchase per Person": thirtytothirtyfour_avg_per_person},
                                       {"Age": "35-39", "Purchase Count": thirtyfivetothirtythirtynine_purchasecount, "Average Purchase Price": thirtyfivetothirtythirtynine_avgpurchase, "Total Purchase Value": thirtyfivetothirtythirtynine_totalpurchase, "Avg Total Purchase per Person": thirtyfivetothirtythirtynine_avg_per_person},
                                       {"Age": "40+", "Purchase Count": fourtyplus_purchasecount, "Average Purchase Price": fourtyplus_avgpurchase, "Total Purchase Value": fourtyplus_totalpurchase, "Avg Total Purchase per Person": fourtyplus_avg_per_person}])

# %%
#Answer to Purchasing Analysis by Age

age_purchasing_analysis = age_purchasing_analysis.set_index("Age")
age_purchasing_analysis.head()
# Out:
#        Average Purchase Price  Avg Total Purchase per Person  Purchase Count  \
# Age
# <10                  3.353478                       4.537059              23
# 10-14                2.956429                       3.762727              28
# 15-19                3.035956                       3.858785             136
# 20-24                3.052219                       4.318062             365
# 25-29                2.900990                       3.805195             101
#
#        Total Purchase Value
# Age
# <10                   77.13
# 10-14                 82.78
# 15-19                412.89
# 20-24               1114.06
# 25-29                293.00

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Answer is given above

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#taking the sum of the table
top_spender_sum = purchase_data.groupby(['SN']).sum()
top_spender_sum.head(10)
# Out:
#               Purchase ID  Age  Item ID  Price
# SN
# Adairialis76          467   16      123   2.28
# Adastirin33           142   35      175   4.48
# Aeda94                388   17      128   4.91
# Aela59                 28   21      119   4.32
# Aelaria33             630   23      171   1.79
# Aelastirin39          984   46      134   7.29
# Aelidru27             705   22      183   1.09
# Aelin32               723   60      326   8.98
# Aelly27               471   48      130   6.79
# Aellynun67            286   25      153   3.74

# %%
#sorting to get the highest at the top
top_spender_sum = top_spender_sum.sort_values(["Price"], ascending=False)
top_spender_sum
# Out:
#                Purchase ID  Age  Item ID  Price
# SN
# Lisosia93             1630  125      451  18.96
# Idastidru52           1999   96      527  15.45
# Chamjask73            1306   66      339  13.83
# Iral74                2285   84      518  13.62
# Iskadarya95            713   60      321  13.10
# Ilarin91              1474   66      243  12.70
# Ialallo29             1097   45      323  11.84
# Tyidaim51             1257   48      153  11.83
# Lassilsala30          1390   63      288  11.51
# Chadolyla44           1000   60      306  11.46
# Iri67                  849   60      342  11.37
# Inguron55              651   69      357  11.11
# Siallylis44           1143   60      284  10.37
# Saistyphos30          1543  105      201  10.33
# Phyali88               520   45      234  10.30
# Strithenu87           1383   60      306  10.18
# Lisim78                312   60      331  10.02
# Haillyrgue51           626   21      134   9.50
# ...

# %%
#Getting the purchase count by player
top_spender_purchase_count = purchase_data["SN"].value_counts()
top_spender_purchase_count
# Out:
# Lisosia93        5
# Iral74           4
# Idastidru52      4
# Chamjask73       3
# Ilarin91         3
# Idai61           3
# Sondastsda82     3
# Asur53           3
# Hada39           3
# Tyidaim51        3
# Hiaral50         3
# Siallylis44      3
# Chamimla85       3
# Tyisur83         3
# Lassilsala30     3
# Chanastnya43     3
# Iri67            3
# Chadolyla44      3
# Haillyrgue51     3
# Pheodaisun84     3
# Saedaiphos46     3
# Phyali88         3
# Aina42           3
# Inguron55        3
# Aelin32          3
# Lisim78          3
# Zontibe81        3
# Iskadarya95      3
# Lisopela58       3
# Saistyphos30     3
#                 ..
# Mindista32       1
# Raisty38         1
# Tyaelaelis94     1
# Syathe73         1
# Ealiril69        1
# Lisirra87        1
# Lassjask63       1
# Frichjask31      1
# Chanilsasda38    1
# Chadjask85       1
# Ili43            1
# Lisosia66        1
# Jiskossa61       1
# Eratiel90        1
# Frichossala54    1
# Sidap51          1
# ...

# %%
#turning this into a dataframe to able to merge 
top_spender_count_df = pd.DataFrame(top_spender_purchase_count)
top_spender_count_df
# Out:
#                SN
# Lisosia93       5
# Iral74          4
# Idastidru52     4
# Chamjask73      3
# Ilarin91        3
# Idai61          3
# Sondastsda82    3
# Asur53          3
# Hada39          3
# Tyidaim51       3
# Hiaral50        3
# Siallylis44     3
# Chamimla85      3
# Tyisur83        3
# Lassilsala30    3
# Chanastnya43    3
# Iri67           3
# Chadolyla44     3
# Haillyrgue51    3
# Pheodaisun84    3
# Saedaiphos46    3
# Phyali88        3
# Aina42          3
# Inguron55       3
# Aelin32         3
# Lisim78         3
# Zontibe81       3
# Iskadarya95     3
# Lisopela58      3
# Saistyphos30    3
# ...            ..
# Mindista32      1
# Raisty38        1
# Tyaelaelis94    1
# Syathe73        1
# Ealiril69       1
# Lisirra87       1
# Lassjask63      1
# Frichjask31     1
# Chanilsasda38   1
# Chadjask85      1
# Ili43           1
# Lisosia66       1
# Jiskossa61      1
# Eratiel90       1
# Frichossala54   1
# Sidap51         1
# Ilosian36       1
# Undista85       1
# ...

# %%
#turning this into a dataframe to able to merge 
top_spender_sum = pd.DataFrame(top_spender_sum)
top_spender_sum
# Out:
#                Purchase ID  Age  Item ID  Price
# SN
# Lisosia93             1630  125      451  18.96
# Idastidru52           1999   96      527  15.45
# Chamjask73            1306   66      339  13.83
# Iral74                2285   84      518  13.62
# Iskadarya95            713   60      321  13.10
# Ilarin91              1474   66      243  12.70
# Ialallo29             1097   45      323  11.84
# Tyidaim51             1257   48      153  11.83
# Lassilsala30          1390   63      288  11.51
# Chadolyla44           1000   60      306  11.46
# Iri67                  849   60      342  11.37
# Inguron55              651   69      357  11.11
# Siallylis44           1143   60      284  10.37
# Saistyphos30          1543  105      201  10.33
# Phyali88               520   45      234  10.30
# Strithenu87           1383   60      306  10.18
# Lisim78                312   60      331  10.02
# Haillyrgue51           626   21      134   9.50
# ...

# %%
#Converted the tables into dataframes but merge is not working
merge_table = pd.merge(top_spender_purchase_count, top_spender_sum, on="SN")
merge_table
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-ac6541ec393f> in <module>()
# ----> 1 merge_table = pd.merge(top_spender_purchase_count, top_spender_sum, on="SN")
#       2 merge_table
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      58                          right_index=right_index, sort=sort, suffixes=suffixes,
#      59                          copy=copy, indicator=indicator,
# ---> 60                          validate=validate)
#      61     return op.get_result()
#      62
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
#taking the sum and dividing by the purchase count to get the average 
avg_purchase_top_spender = top_spender_sum/top_spender_purchase_count
avg_purchase_top_spender.head(10)
# Out:
#               Adairialis76  Adastirin33  Aeda94  Aela59  Aelaria33  \
# SN
# Lisosia93              NaN          NaN     NaN     NaN        NaN
# Idastidru52            NaN          NaN     NaN     NaN        NaN
# Chamjask73             NaN          NaN     NaN     NaN        NaN
# Iral74                 NaN          NaN     NaN     NaN        NaN
# Iskadarya95            NaN          NaN     NaN     NaN        NaN
# Ilarin91               NaN          NaN     NaN     NaN        NaN
# Ialallo29              NaN          NaN     NaN     NaN        NaN
# Tyidaim51              NaN          NaN     NaN     NaN        NaN
# Lassilsala30           NaN          NaN     NaN     NaN        NaN
# Chadolyla44            NaN          NaN     NaN     NaN        NaN
#
#               Aelastirin39  Aelidru27  Aelin32  Aelly27  Aellynun67  \
# SN
# Lisosia93              NaN        NaN      NaN      NaN         NaN
# Idastidru52            NaN        NaN      NaN      NaN         NaN
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Retrieve the Item ID, Item Name, and Item Price columns

popular_items = purchase_data[["Item ID","Item Name","Price"]] 
popular_items
# Out:
#      Item ID                                     Item Name  Price
# 0        108     Extraction, Quickblade Of Trembling Hands   3.53
# 1        143                             Frenzied Scimitar   1.56
# 2         92                                  Final Critic   4.88
# 3        100                                   Blindscythe   3.27
# 4        131                                          Fury   1.44
# 5         81                                     Dreamkiss   3.61
# 6        169        Interrogator, Blood Blade of the Queen   2.18
# 7        162                                 Abyssal Shard   2.67
# 8         21                                     Souleater   1.10
# 9        136                  Ghastly Adamantite Protector   3.58
# 10        95                         Singed Onyx Warscythe   4.74
# 11       162                                 Abyssal Shard   2.67
# 12       116                       Renewed Skeletal Katana   4.18
# ...

# %%
#getting the most popular item IDs

popular_items["Item ID"].value_counts()
# Out:
# 178    12
# 82      9
# 108     9
# 145     9
# 92      8
# 19      8
# 75      8
# 103     8
# 72      8
# 60      8
# 59      8
# 34      8
# 37      8
# 159     7
# 7       7
# 85      7
# 141     7
# 78      7
# 164     7
# 53      7
# 117     7
# 71      7
# 110     7
# 136     6
# 40      6
# 54      6
# 120     6
# 12      6
# 144     6
# 3       6
#        ..
# 176     2
# 177     2
# 18      2
# 158     2
# 69      2
# 43      2
# 31      2
# 132     2
# 63      2
# 26      2
# 28      2
# 56      2
# 30      2
# 127     2
# 33      2
# 115     2
# 125     2
# 48      2
# 126     1
# 23      1
# 180     1
# 47      1
# 90      1
# 134     1
# 91      1
# 42      1
# 118     1
# 104     1
# 27      1
# 51      1
# Name: Item ID, Length: 183, dtype: int64

# %%
#Group by Item ID and Item Name.

popular_item_grouped = popular_items.groupby(["Item ID", "Item Name"])
popular_item_grouped.count().head(5)
# Out:
#                             Price
# Item ID Item Name
# 0       Splinter                4
# 1       Crucifer                3
# 2       Verdict                 6
# 3       Phantomlight            6
# 4       Bloodlord's Fetish      5

# %%
total_purchase_value_popularitem = pd.DataFrame(
    popular_item_grouped["Price"].sum())
total_purchase_value_popularitem.head(10)
# Out:
#                                            Price
# Item ID Item Name
# 0       Splinter                            5.12
# 1       Crucifer                            9.78
# 2       Verdict                            14.88
# 3       Phantomlight                       14.94
# 4       Bloodlord's Fetish                  8.50
# 5       Putrid Fan                         16.32
# 6       Rusty Skull                         7.40
# 7       Thorn, Satchel of Dark Souls        9.31
# 8       Purgatory, Gem of Regret           11.79
# 9       Thorn, Conqueror of the Corrupted  10.92

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame
